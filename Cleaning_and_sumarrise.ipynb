# %%
#import required libraries
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load parquet files into DataFrames
abstract_df = pd.read_parquet('/content/drive/My Drive/ilab dataset/abstract.parquet')
applicants_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/applicants.parquet")
biblio_cited_by_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/biblio_cited_by.parquet")
claims_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/claims.parquet")
classifications_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/classifications.parquet")
descriptions_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/descriptions.parquet")
earliest_claim_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/earliest_claim.parquet")
invention_title_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/invention_title.parquet")
inventors_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/inventors.parquet")
legal_status_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/legal_status.parquet")
main_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/main.parquet")
owners_all_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/owners_all.parquet")
priority_claims_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/priority_claims.parquet")
references_cited_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/references_cited.parquet")
publication_reference_df = pd.read_parquet("/content/drive/My Drive/ilab dataset/publication_reference.parquet")

# %%
merged_df = pd.merge(abstract_df, claims_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, applicants_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, biblio_cited_by_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, classifications_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, descriptions_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, earliest_claim_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, invention_title_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, inventors_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, legal_status_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, main_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, owners_all_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, priority_claims_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, owners_all_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, references_cited_df, on=['lens_id'], how='left')

# %%
merged_df = pd.merge(merged_df, publication_reference_df, on=['lens_id'], how='left')

# %%
merged_df
# Out:
#                     lens_id  \
# 0       041-096-994-434-303
# 1       041-096-994-434-303
# 2       041-096-994-434-303
# 3       041-096-994-434-303
# 4       041-096-994-434-303
# ...                     ...
# 685108  018-441-487-086-771
# 685109  018-441-487-086-771
# 685110  018-441-487-086-771
# 685111  018-441-487-086-771
# 685112  037-429-374-401-592
#
#                                                      text  \
# 0       A system to allocate resources via information...
# 1       A system to allocate resources via information...
# 2       A system to allocate resources via information...
# 3       A system to allocate resources via information...
# 4       A system to allocate resources via information...
# ...                                                   ...
# 685108  This disclosure relates to techniques for a wi...
# 685109  This disclosure relates to techniques for a wi...
# 685110  This disclosure relates to techniques for a wi...
# ...

# %%
print(merged_df.columns)
# Out:
# Index(['lens_id', 'text', 'claim_text', 'applicant_name', 'patent_count',
#        'cited_lens_id', 'cited_jurisdiction', 'cited_doc_number', 'cited_kind',
#        '0', 'symbol', 'description_text', 'date_x', 'invention_title',
#        'inventor_name', 'grant_date', 'granted', 'patent_status',
#        'date_published', 'doc_number_x', 'jurisdiction_x', 'kind_x', 'lang',
#        'owner_name_x', 'address_x', 'country_x', 'execution_date_x',
#        'recorded_date_x', 'jurisdiction_y', 'doc_number_y', 'kind_y', 'date_y',
#        'sequence_x', 'owner_name_y', 'address_y', 'country_y',
#        'execution_date_y', 'recorded_date_y', 'cited_phase', 'sequence_y',
#        'nplcit_lens_id', 'nplcit_text', 'patcit_jurisdiction',
#        'patcit_doc_number', 'patcit_kind', 'patcit_date', 'jurisdiction',
#        'doc_number', 'kind', 'date'],
#       dtype='object')

# %%
# List of column names to keep
columns_to_keep = ["lens_id",
                   "date_published",
                   "jurisdiction",
                   "kind",
                   "text",
                   "description_text",
                   "claim_text",
                   "applicant_name",
                   "invention_title",
                   "inventor_name",
                   "cited_lens_id",
                   "cited_jurisdiction",
                   "cited_kind",
                   "symbol",
                   "grant_date",
                   "granted",
                   "patent_status",
                   "cited_phase",
                   "nplcit_lens_id",
                   "nplcit_text",
                   "patcit_jurisdiction",
                   "patcit_kind"]
# Move the specified columns
#"description_text",
final_new_df = merged_df[columns_to_keep].copy()

# %%
final_new_df
# Out:
#                     lens_id date_published jurisdiction kind  \
# 0       041-096-994-434-303     2019-12-31           US   B2
# 1       041-096-994-434-303     2019-12-31           US   B2
# 2       041-096-994-434-303     2019-12-31           US   B2
# 3       041-096-994-434-303     2019-12-31           US   B2
# 4       041-096-994-434-303     2019-12-31           US   B2
# ...                     ...            ...          ...  ...
# 685108  018-441-487-086-771     2023-01-03           US   B2
# 685109  018-441-487-086-771     2023-01-03           US   B2
# 685110  018-441-487-086-771     2023-01-03           US   B2
# 685111  018-441-487-086-771     2023-01-03           US   B2
# 685112  037-429-374-401-592     2023-01-01           IL    A
#
#                                                      text  \
# 0       A system to allocate resources via information...
# 1       A system to allocate resources via information...
# ...

# %%
# Count missing values in each column
missing_values_count = final_new_df.isna().sum()

# Print the count of missing values in each column
print(missing_values_count)
# Out:
# lens_id                     0
# date_published              0
# jurisdiction                0
# kind                        0
# text                    22986
# description_text         2988
# claim_text               2988
# applicant_name              0
# invention_title             0
# inventor_name            2973
# cited_lens_id          147613
# cited_jurisdiction     147613
# cited_kind             147613
# symbol                   1109
# grant_date             230251
# granted                229003
# patent_status               0
# cited_phase             18832
# nplcit_lens_id         660265
# nplcit_text            575317
# patcit_jurisdiction    128628
# patcit_kind            128628
# dtype: int64

# %%
# Delete rows where 'claim_text' is missing
final_new_df = final_new_df.dropna(subset=['claim_text'])

# %%
final_new_df = final_new_df.dropna(subset=['text'])

# %%
final_new_df
# Out:
#                     lens_id date_published jurisdiction kind  \
# 0       041-096-994-434-303     2019-12-31           US   B2
# 1       041-096-994-434-303     2019-12-31           US   B2
# 2       041-096-994-434-303     2019-12-31           US   B2
# 3       041-096-994-434-303     2019-12-31           US   B2
# 4       041-096-994-434-303     2019-12-31           US   B2
# ...                     ...            ...          ...  ...
# 685107  018-441-487-086-771     2023-01-03           US   B2
# 685108  018-441-487-086-771     2023-01-03           US   B2
# 685109  018-441-487-086-771     2023-01-03           US   B2
# 685110  018-441-487-086-771     2023-01-03           US   B2
# 685111  018-441-487-086-771     2023-01-03           US   B2
#
#                                                      text  \
# 0       A system to allocate resources via information...
# 1       A system to allocate resources via information...
# ...

# %%
pip install bert-extractive-summarizer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 55.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 79.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 25.9 MB/s eta 0:00:00
# ...

# %%
final_new_df['date_published'] = pd.to_datetime(final_new_df['date_published'])
# Filter rows where the year is at least 2023
filtered_df = final_new_df[final_new_df['date_published'].dt.year >= 2023]

# %%
filtered_df
# Out:
#                     lens_id date_published jurisdiction kind  \
# 650745  190-078-393-748-01X     2023-10-05           WO   A1
# 650746  190-078-393-748-01X     2023-10-05           WO   A1
# 650747  190-078-393-748-01X     2023-10-05           WO   A1
# 650748  190-078-393-748-01X     2023-10-05           WO   A1
# 650749  190-078-393-748-01X     2023-10-05           WO   A1
# ...                     ...            ...          ...  ...
# 685107  018-441-487-086-771     2023-01-03           US   B2
# 685108  018-441-487-086-771     2023-01-03           US   B2
# 685109  018-441-487-086-771     2023-01-03           US   B2
# 685110  018-441-487-086-771     2023-01-03           US   B2
# 685111  018-441-487-086-771     2023-01-03           US   B2
#
#                                                      text  \
# 650745  In the present disclosure, various devices and...
# 650746  In the present disclosure, various devices and...
# ...

# %%
test_filtered_df = filtered_df.drop_duplicates(subset="description_text", keep="first")

# %%
test_filtered_df
# Out:
#                     lens_id date_published jurisdiction kind  \
# 650745  190-078-393-748-01X     2023-10-05           WO   A1
# 650884  028-809-963-835-987     2023-10-05           US   A1
# 650894  011-654-511-095-569     2023-10-05           US   A1
# 650906  020-221-942-600-662     2023-10-05           US   A1
# 650926  058-719-716-586-767     2023-10-05           US   A1
# ...                     ...            ...          ...  ...
# 685005  135-184-363-553-38X     2023-01-03           US   B2
# 685011  120-229-536-364-408     2023-01-03           US   B2
# 685031  156-273-454-703-810     2023-01-03           US   B2
# 685060  180-986-575-993-754     2023-01-03           US   B2
# 685072  018-441-487-086-771     2023-01-03           US   B2
#
#                                                      text  \
# 650745  In the present disclosure, various devices and...
# 650884  An automation technology field device includes...
# ...

# %%
# Assuming you want to take a random sample of 100 rows from 'filtered_df'
sample_size = 100  # Adjust this value as needed

# Use the sample method to take a random sample
random_sample = test_filtered_df.sample(n=sample_size, random_state=42)  # 'random_state' for reproducibility

# 'random_sample' now contains a random sample of 100 rows from 'filtered_df'

# %% [markdown]
# Testing on a sample

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load the T5 tokenizer and model for summarization
tokenizer = AutoTokenizer.from_pretrained("t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")

# Create an empty list to store the summaries
summaries = []

# Iterate through each row in the DataFrame and summarize the 'description_text'
for index, row in random_sample.iterrows():
    text_to_summarize = row['description_text']

    # Tokenize the input text
    input_ids = tokenizer.encode("summarize: " + text_to_summarize, return_tensors="pt", max_length=1024, truncation=True)

    # Generate the summary
    summary_ids = model.generate(input_ids, max_length=150, min_length=30, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    # Append the summary to the list
    summaries.append(summary)

# Add the summaries to a new column in the DataFrame
random_sample['summary'] = summaries

# %%
test = random_sample['description_text'].iloc[1]
print(test)
# Out:
# This application is related to U.S. patent application Ser. No. 16/292,317 (titled “Chemical Oxygen Demand Sensing Using Pseudo-Graphite”), Ser. No. 16/292,318 (titled “Chlorine Species Sensing Using Pseudo-Graphite”), Ser. No. 16/292,320 (titled “pH Sensing Using Pseudo-Graphite”), Ser. No. 16/292,322 (titled “Technologies Using Pseudo-Graphite Composites”), and Ser. No. 16/292,323 (titled “Technologies Using Nitrogen-Functionalized Pseudo-Graphite”), all of which were filed on Mar. 5, 2019, by the co-applicants of the present application. The disclosures of the foregoing patent applications are all incorporated herein by reference in their entirety. BACKGROUND The present disclosure relates to technologies using surface-modified pseudo-graphite, and more particularly to the utilization of electrodes with surface-modified pseudo-graphite for performing electrochemical operations such as for detecting chemical species. Generally, some electrodes in a sensor are capable of detecting c
# ...

# %%
summary = random_sample['summary'].iloc[1]
print(summary)
# Out:
# a patent application is related to U.S. patent application Ser. No. 16/292,317. a method of fabricating an electrode may include depositing nano-particles on the pseudo-graphite material surface. the method may also include grafting the amine radicals to the pseudo-graphite material surface.

# %% [markdown]
# Full dataset

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load the T5 tokenizer and model for summarization
tokenizer = AutoTokenizer.from_pretrained("t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")

# Create an empty list to store the summaries
summaries2 = []

# Iterate through each row in the DataFrame and summarize the 'description_text'
for index, row in test_filtered_df.iterrows():
    text_to_summarize = row['description_text']

    # Tokenize the input text
    input_ids = tokenizer.encode("summarize: " + text_to_summarize, return_tensors="pt", max_length=1024, truncation=True)

    # Generate the summary
    summary_ids = model.generate(input_ids, max_length=150, min_length=30, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    # Append the summary to the list
    summaries2.append(summary)

# Add the summaries to a new column in the DataFrame
test_filtered_df['summary'] = summaries2

# %%
final_new_df.to_parquet('/content/drive/My Drive/ilab dataset/final_df.parquet')
