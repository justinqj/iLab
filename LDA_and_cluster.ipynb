# %%
#import required libraries
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/ilab dataset/real_final_df.csv')

# %%
df
# Out:
#                   lens_id date_published kind  \
# 0     000-012-609-013-177     2019-08-29   A1
# 1     000-023-766-650-923     2021-05-13   A1
# 2     000-052-978-540-155     2021-12-09   A1
# 3     000-067-543-894-474     2020-08-25   B1
# 4     000-114-524-168-716     2019-01-22   B2
# ...                   ...            ...  ...
# 9541  199-942-705-542-114     2020-06-16   B2
# 9542  199-948-363-652-539     2022-12-08   A1
# 9543  199-954-040-139-66X     2020-02-27   A1
# 9544  199-958-580-075-44X     2020-12-17   A1
# 9545  199-966-778-173-467     2022-05-26   A1
#
#                                                    text  \
# 0     Systems and methods are provided that leverage...
# 1     Disclosed is a process and system for training...
# 2     Information indicating what technology and ser...
# 3     Systems and methods detecting onboard sensor t...
# 4     A method for generating a control signal to co...
# ...                                                 ...
# 9541  This disclosure describes systems, methods, an...
# 9542  A vehicle comprising a compressor and a manifo...
# 9543  Embodiments are generally directed to hybrid t...
# 9544  The present invention relates to a composition...
# 9545  A bicycle saddle can be customized to a rider'...
#
#                                              claim_text  \
# 0     1 . A method of determining data about natural...
# 1     1 . An information technology system comprisin...
# 2     1 . A technology name and service name generat...
# 3     1. A computer-implemented method in an electro...
# 4     1. A method for generating a control signal to...
# ...                                                 ...
# 9541  1. A device comprising storage coupled to proc...
# 9542  1 . A device comprising: a discrete plate-shap...
# 9543  1 . An apparatus comprising: a TSV array subst...
# 9544  1 . A method of composition analysis of ultram...
# 9545  1 - 54 . (canceled);55 . A customizable bicycl...
#
#                                          applicant_name  \
# 0       EMERSON PROCESS MAN POWER & WATER SOLUTIONS INC
# 1                                   BECTON DICKINSON CO
# 2     GUANGDONG XIANGYI SCIENCE AND TECH INFORMATION...
# 3                                   ZIXCORP SYSTEMS INC
# 4                                            FERRING BV
# ...                                                 ...
# 9541                                FRACTUS ANTENNAS SL
# 9542                                       KANSKAR AMIT
# 9543                                             SAP SE
# 9544                                     SENGUPTA UTTAM
# 9545                                       ZHANG HUIJIE
#
#                                         invention_title  \
# 0     Method, apparatus, server, and systems of time...
# 1     Security door locking structure based on Inter...
# 2     TECHNOLOGIES FOR PROCESSING NETWORK PACKETS IN...
# 3     KONFIGURATIONSVERFAHREN UND -VORRICHTUNG FÜR L...
# 4                           Video conversion technology
# ...                                                 ...
# 9541  TECHNOLOGIES FOR MEMORY-EFFICIENT KEY-VALUE LO...
# 9542  TECHNOLOGIES FOR DEMOTING CACHE LINES TO SHARE...
# 9543  SYSTEM AND METHOD FOR SUPERIMPOSED HANDWRITING...
# 9544  METHOD FOR INTERWORKING AMONG WIRELESS TECHNOL...
# 9545  FIELD-EDITING TECHNOLOGY FOR QUANTUM MATERIALS...
#
#                 inventor_name  \
# 0     BALLAGUET JEAN-PIERRE R
# 1                 LEE HO YOUN
# 2               MENAHEM GABBY
# 3          ZMUDZINSKI KRYSTOF
# 4             MAES STEPHANE H
# ...                       ...
# 9541              WENUS JAKUB
# 9542      BONNEMASOU SINCLAIR
# 9543             JACK BARNETT
# 9544            SHAH PRITAL B
# 9545                 RON AVIV
#
#                                           cited_lens_id cited_jurisdiction  \
# 0                                   178-421-345-280-222                 CN
# 1                                   000-382-027-825-034                 KR
# 2     105-688-517-302-040;094-133-942-377-768;056-37...                 US
# 3     033-063-952-790-261;198-160-552-725-741;012-41...                 US
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 9541                                                NaN                NaN
# 9542                                017-546-397-724-324                 US
# 9543  122-879-772-553-38X;078-776-966-680-613;076-25...              US;CN
# 9544                                041-264-458-726-468                 CN
# 9545                                                NaN                NaN
#
#       ... jurisdiction                                     truncated_text  \
# 0     ...           US  Systems and methods are provided that leverage...
# 1     ...           US  Disclosed is a process and system for training...
# 2     ...           US  Information indicating what technology and ser...
# 3     ...           US  Systems and methods detecting onboard sensor t...
# 4     ...           US  A method for generating a control signal to co...
# ...   ...          ...                                                ...
# 9541  ...           US  This disclosure describes systems, methods, an...
# 9542  ...           US  A vehicle comprising a compressor and a manifo...
# 9543  ...           US  Embodiments are generally directed to hybrid t...
# 9544  ...           US  The present invention relates to a composition...
# 9545  ...           US  A bicycle saddle can be customized to a rider'...
#
#      sentiment                                         categories  \
# 0     POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 1     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 2     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 3     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 4     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# ...        ...                                                ...
# 9541  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 9542  POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 9543  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 9544  POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 9545  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
#
#      Time Horizon Opportunity-Challenge      Likelihood    Degree of Change  \
# 0     Medium term      Some opportunity  Almost Certain       Medium Change
# 1     Medium term        Some challenge        Possible  Substantial Change
# 2     Medium term        Some challenge        Possible  Substantial Change
# 3     Medium term        Some challenge        Possible  Substantial Change
# 4     Medium term        Some challenge        Possible  Substantial Change
# ...           ...                   ...             ...                 ...
# 9541  Medium term        Some challenge        Possible  Substantial Change
# 9542  Medium term      Some opportunity  Almost Certain       Medium Change
# 9543  Medium term        Some challenge        Possible  Substantial Change
# 9544  Medium term      Some opportunity  Almost Certain       Medium Change
# 9545  Medium term        Some challenge        Possible  Substantial Change
#
#              Scale of Impact  \
# 0                    Society
# 1     Individual / Household
# 2     Individual / Household
# 3     Individual / Household
# 4     Individual / Household
# ...                      ...
# 9541  Individual / Household
# 9542                 Society
# 9543  Individual / Household
# 9544                 Society
# 9545  Individual / Household
#
#                                                 summary
# 0     methodological development of SMART is accompl...
# 1     the process and system employ a regenerative c...
# 2     a technology name and service name generation ...
# 3     data captured by interior sensors within a veh...
# 4     a method for generating a control signal to co...
# ...                                                 ...
# 9541                                                NaN
# 9542                                                NaN
# 9543                                                NaN
# 9544                                                NaN
# 9545                                                NaN
#
# [9546 rows x 34 columns]

# %%
print(df.columns)
# Out:
# Index(['lens_id', 'date_published', 'kind', 'text', 'claim_text',
#        'applicant_name', 'invention_title', 'inventor_name', 'cited_lens_id',
#        'cited_jurisdiction', 'cited_kind', 'symbol', 'grant_date', 'granted',
#        'patent_status', 'cited_phase', 'nplcit_lens_id', 'nplcit_text',
#        'patcit_jurisdiction', 'patcit_kind', 'main_cpc', 'sub_cpc',
#        'main_cpc_description', 'sub_cpc_description', 'jurisdiction',
#        'truncated_text', 'sentiment', 'categories', 'Time Horizon',
#        'Opportunity-Challenge', 'Likelihood', 'Degree of Change',
#        'Scale of Impact', 'summary'],
#       dtype='object')

# %%
df['date_published'] = pd.to_datetime(df['date_published'])

# Filter rows where the year is at least 2023
#filtered_df = df[df['date_published'].dt.year >= 2023]

# %%
filtered_df = df

# %%
filtered_df
# Out:
#                   lens_id date_published kind  \
# 0     000-012-609-013-177     2019-08-29   A1
# 1     000-023-766-650-923     2021-05-13   A1
# 2     000-052-978-540-155     2021-12-09   A1
# 3     000-067-543-894-474     2020-08-25   B1
# 4     000-114-524-168-716     2019-01-22   B2
# ...                   ...            ...  ...
# 9541  199-942-705-542-114     2020-06-16   B2
# 9542  199-948-363-652-539     2022-12-08   A1
# 9543  199-954-040-139-66X     2020-02-27   A1
# 9544  199-958-580-075-44X     2020-12-17   A1
# 9545  199-966-778-173-467     2022-05-26   A1
#
#                                                    text  \
# 0     Systems and methods are provided that leverage...
# 1     Disclosed is a process and system for training...
# 2     Information indicating what technology and ser...
# 3     Systems and methods detecting onboard sensor t...
# 4     A method for generating a control signal to co...
# ...                                                 ...
# 9541  This disclosure describes systems, methods, an...
# 9542  A vehicle comprising a compressor and a manifo...
# 9543  Embodiments are generally directed to hybrid t...
# 9544  The present invention relates to a composition...
# 9545  A bicycle saddle can be customized to a rider'...
#
#                                              claim_text  \
# 0     1 . A method of determining data about natural...
# 1     1 . An information technology system comprisin...
# 2     1 . A technology name and service name generat...
# 3     1. A computer-implemented method in an electro...
# 4     1. A method for generating a control signal to...
# ...                                                 ...
# 9541  1. A device comprising storage coupled to proc...
# 9542  1 . A device comprising: a discrete plate-shap...
# 9543  1 . An apparatus comprising: a TSV array subst...
# 9544  1 . A method of composition analysis of ultram...
# 9545  1 - 54 . (canceled);55 . A customizable bicycl...
#
#                                          applicant_name  \
# 0       EMERSON PROCESS MAN POWER & WATER SOLUTIONS INC
# 1                                   BECTON DICKINSON CO
# 2     GUANGDONG XIANGYI SCIENCE AND TECH INFORMATION...
# 3                                   ZIXCORP SYSTEMS INC
# 4                                            FERRING BV
# ...                                                 ...
# 9541                                FRACTUS ANTENNAS SL
# 9542                                       KANSKAR AMIT
# 9543                                             SAP SE
# 9544                                     SENGUPTA UTTAM
# 9545                                       ZHANG HUIJIE
#
#                                         invention_title  \
# 0     Method, apparatus, server, and systems of time...
# 1     Security door locking structure based on Inter...
# 2     TECHNOLOGIES FOR PROCESSING NETWORK PACKETS IN...
# 3     KONFIGURATIONSVERFAHREN UND -VORRICHTUNG FÜR L...
# 4                           Video conversion technology
# ...                                                 ...
# 9541  TECHNOLOGIES FOR MEMORY-EFFICIENT KEY-VALUE LO...
# 9542  TECHNOLOGIES FOR DEMOTING CACHE LINES TO SHARE...
# 9543  SYSTEM AND METHOD FOR SUPERIMPOSED HANDWRITING...
# 9544  METHOD FOR INTERWORKING AMONG WIRELESS TECHNOL...
# 9545  FIELD-EDITING TECHNOLOGY FOR QUANTUM MATERIALS...
#
#                 inventor_name  \
# 0     BALLAGUET JEAN-PIERRE R
# 1                 LEE HO YOUN
# 2               MENAHEM GABBY
# 3          ZMUDZINSKI KRYSTOF
# 4             MAES STEPHANE H
# ...                       ...
# 9541              WENUS JAKUB
# 9542      BONNEMASOU SINCLAIR
# 9543             JACK BARNETT
# 9544            SHAH PRITAL B
# 9545                 RON AVIV
#
#                                           cited_lens_id cited_jurisdiction  \
# 0                                   178-421-345-280-222                 CN
# 1                                   000-382-027-825-034                 KR
# 2     105-688-517-302-040;094-133-942-377-768;056-37...                 US
# 3     033-063-952-790-261;198-160-552-725-741;012-41...                 US
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 9541                                                NaN                NaN
# 9542                                017-546-397-724-324                 US
# 9543  122-879-772-553-38X;078-776-966-680-613;076-25...              US;CN
# 9544                                041-264-458-726-468                 CN
# 9545                                                NaN                NaN
#
#       ... jurisdiction                                     truncated_text  \
# 0     ...           US  Systems and methods are provided that leverage...
# 1     ...           US  Disclosed is a process and system for training...
# 2     ...           US  Information indicating what technology and ser...
# 3     ...           US  Systems and methods detecting onboard sensor t...
# 4     ...           US  A method for generating a control signal to co...
# ...   ...          ...                                                ...
# 9541  ...           US  This disclosure describes systems, methods, an...
# 9542  ...           US  A vehicle comprising a compressor and a manifo...
# 9543  ...           US  Embodiments are generally directed to hybrid t...
# 9544  ...           US  The present invention relates to a composition...
# 9545  ...           US  A bicycle saddle can be customized to a rider'...
#
#      sentiment                                         categories  \
# 0     POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 1     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 2     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 3     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 4     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# ...        ...                                                ...
# 9541  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 9542  POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 9543  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 9544  POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 9545  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
#
#      Time Horizon Opportunity-Challenge      Likelihood    Degree of Change  \
# 0     Medium term      Some opportunity  Almost Certain       Medium Change
# 1     Medium term        Some challenge        Possible  Substantial Change
# 2     Medium term        Some challenge        Possible  Substantial Change
# 3     Medium term        Some challenge        Possible  Substantial Change
# 4     Medium term        Some challenge        Possible  Substantial Change
# ...           ...                   ...             ...                 ...
# 9541  Medium term        Some challenge        Possible  Substantial Change
# 9542  Medium term      Some opportunity  Almost Certain       Medium Change
# 9543  Medium term        Some challenge        Possible  Substantial Change
# 9544  Medium term      Some opportunity  Almost Certain       Medium Change
# 9545  Medium term        Some challenge        Possible  Substantial Change
#
#              Scale of Impact  \
# 0                    Society
# 1     Individual / Household
# 2     Individual / Household
# 3     Individual / Household
# 4     Individual / Household
# ...                      ...
# 9541  Individual / Household
# 9542                 Society
# 9543  Individual / Household
# 9544                 Society
# 9545  Individual / Household
#
#                                                 summary
# 0     methodological development of SMART is accompl...
# 1     the process and system employ a regenerative c...
# 2     a technology name and service name generation ...
# 3     data captured by interior sensors within a veh...
# 4     a method for generating a control signal to co...
# ...                                                 ...
# 9541                                                NaN
# 9542                                                NaN
# 9543                                                NaN
# 9544                                                NaN
# 9545                                                NaN
#
# [9546 rows x 34 columns]

# %%
# Trim whitespace from text columns
text_columns = ['text', 'claim_text', 'invention_title', 'inventor_name']
for col in text_columns:
    filtered_df[col] = filtered_df[col].str.strip()

# Convert text columns to lowercase
for col in text_columns:
    filtered_df[col] = filtered_df[col].str.lower()

# %%
filtered_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Remove punctuation and numbers

# %%
import string

text_columns = ['text', 'claim_text', 'invention_title']

def remove_punctuation_and_numbers(text):
    if not isinstance(text, str):  # Check if the input is a string
        return text  # If not, return the input as it is
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove numbers
    text = ''.join([i for i in text if not i.isdigit()])
    return text


for col in text_columns:
    filtered_df[col] = filtered_df[col].apply(remove_punctuation_and_numbers)

# %%
filtered_df
# Out:
#                   lens_id date_published kind  \
# 0     000-012-609-013-177     2019-08-29   A1
# 1     000-023-766-650-923     2021-05-13   A1
# 2     000-052-978-540-155     2021-12-09   A1
# 3     000-067-543-894-474     2020-08-25   B1
# 4     000-114-524-168-716     2019-01-22   B2
# ...                   ...            ...  ...
# 9541  199-942-705-542-114     2020-06-16   B2
# 9542  199-948-363-652-539     2022-12-08   A1
# 9543  199-954-040-139-66X     2020-02-27   A1
# 9544  199-958-580-075-44X     2020-12-17   A1
# 9545  199-966-778-173-467     2022-05-26   A1
#
#                                                    text  \
# 0     systems and methods are provided that leverage...
# 1     disclosed is a process and system for training...
# 2     information indicating what technology and ser...
# 3     systems and methods detecting onboard sensor t...
# 4     a method for generating a control signal to co...
# ...                                                 ...
# 9541  this disclosure describes systems methods and ...
# 9542  a vehicle comprising a compressor and a manifo...
# 9543  embodiments are generally directed to hybrid t...
# 9544  the present invention relates to a composition...
# 9545  a bicycle saddle can be customized to a riders...
#
#                                              claim_text  \
# 0       a method of determining data about natural p...
# 1       an information technology system comprising ...
# 2       a technology name and service name generatio...
# 3      a computerimplemented method in an electronic...
# 4      a method for generating a control signal to c...
# ...                                                 ...
# 9541   a device comprising storage coupled to proces...
# 9542    a device comprising a discrete plateshaped m...
# 9543    an apparatus comprising a tsv array substrat...
# 9544    a method of composition analysis of ultramic...
# 9545      canceled  a customizable bicycle saddle co...
#
#                                          applicant_name  \
# 0       EMERSON PROCESS MAN POWER & WATER SOLUTIONS INC
# 1                                   BECTON DICKINSON CO
# 2     GUANGDONG XIANGYI SCIENCE AND TECH INFORMATION...
# 3                                   ZIXCORP SYSTEMS INC
# 4                                            FERRING BV
# ...                                                 ...
# 9541                                FRACTUS ANTENNAS SL
# 9542                                       KANSKAR AMIT
# 9543                                             SAP SE
# 9544                                     SENGUPTA UTTAM
# 9545                                       ZHANG HUIJIE
#
#                                         invention_title  \
# 0     method apparatus server and systems of timerev...
# 1     security door locking structure based on inter...
# 2     technologies for processing network packets in...
# 3     konfigurationsverfahren und vorrichtung für lu...
# 4                           video conversion technology
# ...                                                 ...
# 9541   technologies for memoryefficient keyvalue lookup
# 9542  technologies for demoting cache lines to share...
# 9543  system and method for superimposed handwriting...
# 9544  method for interworking among wireless technol...
# 9545  fieldediting technology for quantum materials ...
#
#                 inventor_name  \
# 0     ballaguet jean-pierre r
# 1                 lee ho youn
# 2               menahem gabby
# 3          zmudzinski krystof
# 4             maes stephane h
# ...                       ...
# 9541              wenus jakub
# 9542      bonnemasou sinclair
# 9543             jack barnett
# 9544            shah prital b
# 9545                 ron aviv
#
#                                           cited_lens_id cited_jurisdiction  \
# 0                                   178-421-345-280-222                 CN
# 1                                   000-382-027-825-034                 KR
# 2     105-688-517-302-040;094-133-942-377-768;056-37...                 US
# 3     033-063-952-790-261;198-160-552-725-741;012-41...                 US
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 9541                                                NaN                NaN
# 9542                                017-546-397-724-324                 US
# 9543  122-879-772-553-38X;078-776-966-680-613;076-25...              US;CN
# 9544                                041-264-458-726-468                 CN
# 9545                                                NaN                NaN
#
#       ... jurisdiction                                     truncated_text  \
# 0     ...           US  Systems and methods are provided that leverage...
# 1     ...           US  Disclosed is a process and system for training...
# 2     ...           US  Information indicating what technology and ser...
# 3     ...           US  Systems and methods detecting onboard sensor t...
# 4     ...           US  A method for generating a control signal to co...
# ...   ...          ...                                                ...
# 9541  ...           US  This disclosure describes systems, methods, an...
# 9542  ...           US  A vehicle comprising a compressor and a manifo...
# 9543  ...           US  Embodiments are generally directed to hybrid t...
# 9544  ...           US  The present invention relates to a composition...
# 9545  ...           US  A bicycle saddle can be customized to a rider'...
#
#      sentiment                                         categories  \
# 0     POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 1     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 2     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 3     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 4     NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# ...        ...                                                ...
# 9541  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 9542  POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 9543  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
# 9544  POSITIVE  ['Trust', 'Transparent', 'Empowerment', 'Integ...
# 9545  NEGATIVE  ['Mistrust', 'Opaque', 'Disempowerment', 'Frag...
#
#      Time Horizon Opportunity-Challenge      Likelihood    Degree of Change  \
# 0     Medium term      Some opportunity  Almost Certain       Medium Change
# 1     Medium term        Some challenge        Possible  Substantial Change
# 2     Medium term        Some challenge        Possible  Substantial Change
# 3     Medium term        Some challenge        Possible  Substantial Change
# 4     Medium term        Some challenge        Possible  Substantial Change
# ...           ...                   ...             ...                 ...
# 9541  Medium term        Some challenge        Possible  Substantial Change
# 9542  Medium term      Some opportunity  Almost Certain       Medium Change
# 9543  Medium term        Some challenge        Possible  Substantial Change
# 9544  Medium term      Some opportunity  Almost Certain       Medium Change
# 9545  Medium term        Some challenge        Possible  Substantial Change
#
#              Scale of Impact  \
# 0                    Society
# 1     Individual / Household
# 2     Individual / Household
# 3     Individual / Household
# 4     Individual / Household
# ...                      ...
# 9541  Individual / Household
# 9542                 Society
# 9543  Individual / Household
# 9544                 Society
# 9545  Individual / Household
#
#                                                 summary
# 0     methodological development of SMART is accompl...
# 1     the process and system employ a regenerative c...
# 2     a technology name and service name generation ...
# 3     data captured by interior sensors within a veh...
# 4     a method for generating a control signal to co...
# ...                                                 ...
# 9541                                                NaN
# 9542                                                NaN
# 9543                                                NaN
# 9544                                                NaN
# 9545                                                NaN
#
# [9546 rows x 34 columns]

# %% [markdown]
# Remove stopwords

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
# Define the stopwords
stop_words = set(stopwords.words('english'))

# Define custom stopwords
custom_stopwords = {'technology', 'technologies', 'tech', 'technological', 'method', 'second'}

# Add custom stopwords to the stop_words set
stop_words.update(custom_stopwords)

def remove_stopwords(text):
    # Ensure the text is a string
    text = str(text)
    return ' '.join([word for word in text.split() if word not in stop_words])

# Apply the function to each text column
for col in text_columns:
    # Fill NaN with empty string
    filtered_df[col] = filtered_df[col].fillna('')
    filtered_df[col] = filtered_df[col].apply(remove_stopwords)

# %% [markdown]
# Stemming/Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    return ' '.join([lemmatizer.lemmatize(word) for word in text.split()])

for col in text_columns:
    filtered_df[col] = filtered_df[col].apply(lemmatize_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# Initialize the TF-IDF Vectorizer
vectorizer = TfidfVectorizer(max_features=1000, ngram_range=(2, 3))

# For simplicity, let's consider the 'abstract_text' column for keyword extraction
tfidf_matrix = vectorizer.fit_transform(filtered_df['text'])

# Get feature names (keywords/phrases)
feature_names = vectorizer.get_feature_names_out()

def get_top_keywords(tfidf_matrix, feature_names, n=10):
    '''Get top n keywords for each document in the matrix.'''
    keywords_list = []
    dense_matrix = tfidf_matrix.todense()
    for doc in dense_matrix:
        sorted_indices = np.argsort(doc)
        top_indices = sorted_indices[0, -n:]
        keywords = [feature_names[i] for i in top_indices[0, ::-1].tolist()[0]]
        keywords_list.append(keywords)
    return keywords_list

filtered_df['top_keywords'] = get_top_keywords(tfidf_matrix, feature_names)

# %%
filtered_df['top_keywords']
# Out:
# 0       [method provided, neural network, system metho...
# 1       [xps xrf, different first, disclosed illustrat...
# 2       [unit configured, configured perform, configur...
# 3       [vehicle operator, may generated, data may, ve...
# 4       [light source, control signal, positioned with...
#                               ...
# 9541    [may determine, device may determine, device m...
# 9542    [xps xrf, different first, disclosed illustrat...
# 9543    [apparatus includes, substrate first, xps xrf,...
# 9544    [thin film, present invention relates, inventi...
# 9545    [least one, xps xrf, device wireless communica...
# Name: top_keywords, Length: 9546, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

filtered_df['concatenated_text'] = filtered_df['text'].fillna('') + ' ' + filtered_df['invention_title'].fillna('') + ' ' + filtered_df['claim_text'].fillna('')

# Create a vectorizer instance
vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
data_vectorized = vectorizer.fit_transform(filtered_df['concatenated_text'])

# %%
from sklearn.decomposition import LatentDirichletAllocation

# 2. Apply LDA
num_topics = 10  # You can change this number based on your requirements
lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda_model.fit(data_vectorized)
# Out:
# LatentDirichletAllocation(random_state=42)

# %%
# 3. Display the top words for each topic
def print_top_words(model, feature_names, n_top_words=10):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)

feature_names = vectorizer.get_feature_names_out()
print_top_words(lda_model, feature_names)
# Out:
# Topic #0: end portion assembly surface fluid configured device element plurality housing
# Topic #1: device user data plurality service based information application associated network
# Topic #2: signal content terminal sequence circuit output power voltage cell comprises
# Topic #3: layer region substrate material device structure surface semiconductor electrode plurality
# Topic #4: said according composition group cnxpt selected step map weight comprises
# Topic #5: data sensor image based vehicle device user set processor configured
# Topic #6: data plurality transaction blockchain computer node based block set comprises
# Topic #7: device data memory computing network comprises compute response storage medium
# Topic #8: communication rat radio network wireless access ue information node message
# Topic #9: device control energy power temperature unit stream configured gas according

# %%
# Get the topic distribution for documents
doc_topic_dist = lda_model.transform(data_vectorized)

# Assign dominant topic for each document
filtered_df['dominant_topic'] = doc_topic_dist.argmax(axis=1)

# Define a dictionary to map topic numbers to topic names
topic_names = {
    0: "End Portion and Fluid Assembly",
    1: "User-Centric Devices and Services",
    2: "Electrical Signals and Circuits",
    3: "Semiconductor and Material Structures",
    4: "Composition and Steps",
    5: "Sensor-Based Vehicle Systems",
    6: "Blockchain and Computer Transactions",
    7: "Data Storage and Computing Networks",
    8: "Wireless Communication and Networks",
    9: "Device Control and Energy Management"
}

# Replace the values in 'dominant_topic' using the topic_names dictionary
filtered_df['dominant_topic'] = filtered_df['dominant_topic'].replace(topic_names)

# %%
# Convert the 'date_published' column to datetime format
filtered_df['date_published'] = pd.to_datetime(filtered_df['date_published'])

# Create a 'year_month' column in the format 'YYYY-MM'
filtered_df['year_month'] = filtered_df['date_published'].dt.strftime('%Y-%m')

# Group by year and dominant topic
topic_counts = filtered_df.groupby(['year_month', 'dominant_topic']).size().reset_index(name='counts')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,10))
sns.lineplot(data=topic_counts, x='year_month', y='counts', hue='dominant_topic', marker='o')
plt.title('Temporal Analysis of Topics')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Clustering

# %%
test_filtered_df = filtered_df.drop_duplicates(subset="text", keep="first")

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.34.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
from transformers import LongformerModel, LongformerTokenizer
import torch

# Load Longformer2Roberta model and tokenizer
model_name = "allenai/longformer-base-4096"
tokenizer = LongformerTokenizer.from_pretrained(model_name)
model = LongformerModel.from_pretrained(model_name)

# Extract the 'text' column from filtered_df
texts = test_filtered_df['text'].tolist()

# Initialize a list to store embeddings
embeddings_list = []

# Tokenize and obtain embeddings for each row
for text in texts:
    # Tokenize and encode the text data
    input_ids = tokenizer(text, padding=True, truncation=True, return_tensors="pt")

    # Obtain embeddings
    with torch.no_grad():
        outputs = model(**input_ids)
    embeddings = outputs.last_hidden_state

    # Append the embeddings to the list
    embeddings_list.append(embeddings)

# 'embeddings_list' now contains embeddings for each row in the 'text' column using the Longformer2Roberta model.
# Out:
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/597M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-184801267eb3> in <cell line: 16>()
#      20     # Obtain embeddings
#      21     with torch.no_grad():
# ---> 22         outputs = model(**input_ids)
#      23     embeddings = outputs.last_hidden_state
#      24
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/longformer/modeling_longformer.py in forward(self, input_ids, attention_mask, global_attention_mask, head_mask, token_type_ids, position_ids, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1745         )
#    1746
# -> 1747         encoder_outputs = self.encoder(
#    1748             embedding_output,
#    1749             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/longformer/modeling_longformer.py in forward(self, hidden_states, attention_mask, head_mask, padding_len, output_attentions, output_hidden_states, return_dict)
#    1321                 )
#    1322             else:
# -> 1323                 layer_outputs = layer_module(
#    1324                     hidden_states,
#    1325                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/longformer/modeling_longformer.py in forward(self, hidden_states, attention_mask, layer_head_mask, is_index_masked, is_index_global_attn, is_global_attn, output_attentions)
#    1256         outputs = self_attn_outputs[1:]
#    1257
# -> 1258         layer_output = apply_chunking_to_forward(
#    1259             self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attn_output
#    1260         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     238         return torch.cat(output_chunks, dim=chunk_dim)
#     239
# --> 240     return forward_fn(*input_tensors)
#     241
#     242
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/longformer/modeling_longformer.py in ff_chunk(self, attn_output)
#    1263
#    1264     def ff_chunk(self, attn_output):
# -> 1265         intermediate_output = self.intermediate(attn_output)
#    1266         layer_output = self.output(intermediate_output, attn_output)
#    1267         return layer_output
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/longformer/modeling_longformer.py in forward(self, hidden_states)
#    1205
#    1206     def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# -> 1207         hidden_states = self.dense(hidden_states)
#    1208         hidden_states = self.intermediate_act_fn(hidden_states)
#    1209         return hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import KMeans
import numpy as np

# Convert the list of embeddings to a numpy array
embeddings_array = np.vstack(embeddings_list)

# Specify the number of clusters
num_clusters = 10  # Adjust this based on data

# Perform K-Means clustering
kmeans = KMeans(n_clusters=num_clusters)
cluster_labels = kmeans.fit_predict(embeddings_array)

# Assign cluster labels to your DataFrame
test_filtered_df['cluster'] = cluster_labels
